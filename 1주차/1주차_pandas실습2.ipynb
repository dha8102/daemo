# %% [markdown]
# ## 한국 경마 2014년도 데이터
#
# - 데이터셋 다운로드
#     - https://www.kaggle.com/parksami/koreahorseracedata
#
# - 아래의 문제를 풀어 봅시다.
#     * 결측치를 제거한 후,
#     1. 1등을 가장 많이 한 말 이름은?
#     2. 어떤 성별을 가진 말이 성적(3위이내)이 좋을까?

# %% [markdown]
# ### 0. Load Dataset

# %% [markdown]
# #### 0.1 Race
#
# - race.csv 파일을 euc-kr 인코딩으로 로딩
# - Race DataFrame
#     - RCTRCK : race track
#     - RACE_DE : race date
#     - RACE_NO : race number
#     - RCHOSE_NM : race horse name

# %% [markdown]
# ##### load dataset

# %%
import pandas as pd
import numpy as np

# %%
df_race_o = pd.read_csv("./race.csv", encoding="euc-kr")
df_race_o.tail()
# Out:
#           ID RCTRCK     RACE_DE  RACE_NO  PARTCPT_NO  RANK RCHOSE_NM HRSMN  \
# 27213  27214     제주  2014-11-29        9           4   2.0      황용신화   이재웅
# 27214  27215     제주  2014-11-29        4           5   2.0      백록장원   장우성
# 27215  27216     제주  2014-11-29        4           3   7.0      산정무한   안득수
# 27216  27217     제주  2014-11-29        9           7   6.0      미주여행   김경휴
# 27217  27218     제주  2014-11-29        9           6   1.0       철옹성   장우성
#
#            RCORD ARVL_DFFRNC EACH_SCTN_PASAGE_RANK  A_WIN_SYTM_EXPECT_ALOT  \
# 27213  0:01:27.1          2½   4 -  -  - 5 - 5 - 2                     1.8
# 27214  0:01:19.9          머리   7 -  -  - 7 - 6 - 4                     3.5
# 27215  0:01:22.8          1½   4 -  -  - 4 - 4 - 6                    30.9
# 27216  0:01:31.1          13   2 -  -  - 2 - 3 - 6                     6.2
# 27217  0:01:26.6         NaN   1 -  -  - 1 - 1 - 1                     3.9
#
#        WIN_STA_EXPECT_ALOT
# 27213                  2.2
# ...

# %% [markdown]
# ##### Remove columns
# - df_race_o 에서 ID ~ RCODE 컬럼까지만 저장하고, 나머지 열은 제거해 주세요.

# %%
df_race_o = '구현해 주세요'
df_race_o.tail()
# Out:
#           ID RCTRCK     RACE_DE  RACE_NO  PARTCPT_NO  RANK RCHOSE_NM HRSMN  \
# 27213  27214     제주  2014-11-29        9           4   2.0      황용신화   이재웅
# 27214  27215     제주  2014-11-29        4           5   2.0      백록장원   장우성
# 27215  27216     제주  2014-11-29        4           3   7.0      산정무한   안득수
# 27216  27217     제주  2014-11-29        9           7   6.0      미주여행   김경휴
# 27217  27218     제주  2014-11-29        9           6   1.0       철옹성   장우성
#
#            RCORD
# 27213  0:01:27.1
# 27214  0:01:19.9
# 27215  0:01:22.8
# 27216  0:01:31.1
# 27217  0:01:26.6

# %% [markdown]
# ##### NaN 데이터 삭제

# %% [markdown]
# 위의 df_race_o에서 Null이 있는 행 데이터를 제거하여 df_race 라는 변수에 넣어 주세요. reset_index도 수행해 주세요.

# %%
'구현해 주세요'
df_race[-15:-10]
# Out:
#           ID RCTRCK     RACE_DE  RACE_NO  PARTCPT_NO  RANK RCHOSE_NM HRSMN  \
# 26404  27203     제주  2014-11-29       10           1   7.0      가속대왕   김대연
# 26405  27204     제주  2014-11-29       10           5   2.0      천하호령   권동석
# 26406  27206     제주  2014-11-29        6           3   7.0     행복한시간   김홍권
# 26407  27207     제주  2014-11-29        6           4   3.0      소원풀이   전현준
# 26408  27208     제주  2014-11-29        6           5   9.0      꿈이가득   김대연
#
#            RCORD
# 26404  0:01:14.3
# 26405  0:01:11.6
# 26406  0:01:07.2
# 26407  0:01:04.7
# 26408  0:01:07.9

# %% [markdown]
# #### 0.2 Horse
# - horse.csv 파일을 euc-kr 인코딩으로 로딩
# - Horse DataFrame
#     - RCHOSE_BDWGH : race horse body weight

# %% [markdown]
# ##### load dataset

# %%
df_horse_o = pd.read_csv('horse.csv', encoding='euc-kr')
df_horse_o.tail()
# Out:
#           ID RCTRCK     RACE_DE PRDCTN_NATION_NM SEX  AGE  BND_WT TRNER  \
# 27213  27214     제주  2014-11-29                한   거  NaN    56.0   강대은
# 27214  27215     제주  2014-11-29                한   거  NaN    55.5   박병진
# 27215  27216     제주  2014-11-29                한   거  NaN    52.5   김영래
# 27216  27217     제주  2014-11-29                한   거  NaN    53.0   강대은
# 27217  27218     제주  2014-11-29                한   거  NaN    57.5   박병진
#
#       RCHOSE_OWNR_NM  RCHOSE_BDWGH
# 27213            김영구           300
# 27214            고경수           300
# 27215           광명종합           333
# 27216            김기준           281
# 27217            강상우           314

# %% [markdown]
# 위의 df_horse_o에서 Null이 있는 데이터를 확인해 주시고, 제거하여 df_horse 라는 변수에 넣어 주세요.

# %%
'구현해 주세요'
df_horse
# Out:
#           ID RCTRCK     RACE_DE PRDCTN_NATION_NM SEX  BND_WT TRNER  \
# 0          1     부경  2014-01-03                호   수    51.0   윤주혁
# 1          2     부경  2014-01-03                한   거    55.0   오문식
# 2          3     부경  2014-01-03                한   거    54.0   장세한
# 3          4     부경  2014-01-03                미   거    56.0   한상복
# 4          5     부경  2014-01-03                한   수    54.0   권승주
# ...      ...    ...         ...              ...  ..     ...   ...
# 27213  27214     제주  2014-11-29                한   거    56.0   강대은
# 27214  27215     제주  2014-11-29                한   거    55.5   박병진
# 27215  27216     제주  2014-11-29                한   거    52.5   김영래
# 27216  27217     제주  2014-11-29                한   거    53.0   강대은
# 27217  27218     제주  2014-11-29                한   거    57.5   박병진
#
#       RCHOSE_OWNR_NM  RCHOSE_BDWGH
# 0                최상배           474
# 1                류주영           470
# 2                양국만           488
# ...

# %% [markdown]
# ### 1. 1등을 가장 많이 한 말 이름은?

# %% [markdown]
#  df_race에서 1등한 데이터만 필터링한 후 groupby를 이용하여 말 이름별로 1등한 횟수 데이터 프레임을 출력해 주세요.

# %%
df_rank_1 ='구현해 주세요'
df_rank_1.tail()
# Out:
#      RCHOSE_NM  count
# 1560       히어로      1
# 1561     히트포인트      1
# 1562        힐링      5
# 1563        힐톱      4
# 1564      힘찬활력      1

# %% [markdown]
# 가장 많이 1등을 한 횟수와 말의 이름을 출력해 주세요.

# %%
df_rank_1 = '구현해 주세요'
'구현해 주세요'
# Out:
# (7, ['가리사니', '한강의기적'])

# %% [markdown]
# ### 2. 어떤 성별을 가진 말이 성적이 좋을까?
#
# - race 데이터 프레임 : 성적데이터가 있음
# - horse 데이터 프레임 : 성별 데이터가 있음
# - race 데이터와 horse 데이터를 ID를 key값으로 merge

# %%
df_race.tail(3)
# Out:
#           ID RCTRCK     RACE_DE  RACE_NO  PARTCPT_NO  RANK RCHOSE_NM HRSMN  \
# 26416  27216     제주  2014-11-29        4           3   7.0      산정무한   안득수
# 26417  27217     제주  2014-11-29        9           7   6.0      미주여행   김경휴
# 26418  27218     제주  2014-11-29        9           6   1.0       철옹성   장우성
#
#            RCORD
# 26416  0:01:22.8
# 26417  0:01:31.1
# 26418  0:01:26.6

# %%
df_horse.tail(3)
# Out:
#           ID RCTRCK     RACE_DE PRDCTN_NATION_NM SEX  BND_WT TRNER  \
# 27215  27216     제주  2014-11-29                한   거    52.5   김영래
# 27216  27217     제주  2014-11-29                한   거    53.0   강대은
# 27217  27218     제주  2014-11-29                한   거    57.5   박병진
#
#       RCHOSE_OWNR_NM  RCHOSE_BDWGH
# 27215           광명종합           333
# 27216            김기준           281
# 27217            강상우           314

# %%
df_merged = pd.merge(df_race, df_horse)
df_merged.tail(3)
# Out:
#           ID RCTRCK     RACE_DE  RACE_NO  PARTCPT_NO  RANK RCHOSE_NM HRSMN  \
# 26416  27216     제주  2014-11-29        4           3   7.0      산정무한   안득수
# 26417  27217     제주  2014-11-29        9           7   6.0      미주여행   김경휴
# 26418  27218     제주  2014-11-29        9           6   1.0       철옹성   장우성
#
#            RCORD PRDCTN_NATION_NM SEX  BND_WT TRNER RCHOSE_OWNR_NM  \
# 26416  0:01:22.8                한   거    52.5   김영래           광명종합
# 26417  0:01:31.1                한   거    53.0   강대은            김기준
# 26418  0:01:26.6                한   거    57.5   박병진            강상우
#
#        RCHOSE_BDWGH
# 26416           333
# 26417           281
# 26418           314

# %% [markdown]
# 각 랭킹별로 어떤 성별이 얼마나 있는지 피봇 테이블을 만들어 주세요.

# %%
df_merged["COUNT"] = 1
df = '구현해 주세요'
df.head()
# Out:
# SEX       거       수       암
# RANK
# 1.0   528.0  1067.0   964.0
# 2.0   488.0  1033.0  1021.0
# 3.0   538.0   984.0  1029.0
# 4.0   524.0   947.0  1082.0
# 5.0   502.0   897.0  1148.0

# %% [markdown]
# 위 데이터프레임에서 각 성별별로 총 몇 번 나왔는지 groupby를 통해 확인해 보세요.

# %%
# 성별에 대한 전체 데이터
count = '구현해 주세요'
count
# Out:
# SEX
# 거     5400
# 수     9557
# 암    11462
# dtype: int64

# %% [markdown]
# 위 정보를 가지고 df를 확률 형태로 변경해 주세요. 반올림은 소수 둘째자리까지 해 주세요.

# %%
# broad casting을 활용하여 확률 데이터로 변경
'구현해 주세요'
df.head()
# Out:
# SEX      거      수      암
# RANK
# 1.0   9.78  11.16   8.41
# 2.0   9.04  10.81   8.91
# 3.0   9.96  10.30   8.98
# 4.0   9.70   9.91   9.44
# 5.0   9.30   9.39  10.02

# %% [markdown]
# 위 자료로 미루어 볼 때 수컷이 가장 좋은 성적을 낼 확률이 높다는 사실을 알 수 있습니다.
